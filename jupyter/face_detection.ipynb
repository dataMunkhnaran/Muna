# %%
from deepface import DeepFace
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# Бүтэн биш нүүрэн дээр ажиллахгүй

# %%
test = DeepFace.verify(img1_path = "donald1.jfif", img2_path = "donald3.jfif")
print(test)
# Out:
# {'verified': True, 'distance': 0.34804073583713735, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 111, 'y': 35, 'w': 109, 'h': 109}, 'img2': {'x': 64, 'y': 60, 'w': 57, 'h': 57}}, 'time': 0.84}

# %%
img= mpimg.imread('donald1.jfif')
img1=mpimg.imread('donald3.jfif')
fig = plt.figure(figsize=(10, 3))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img1)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Бүтэн биш нүүрэн дээр ажиллахгүй

# %%
dfs = DeepFace.find(img_path = "img1.jpg", db_path = "C:/Users/Owner/Documents/python/my_db")

# %%
print(dfs)
# Out:
# [Empty DataFrame
# Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
# Index: []]

# %%
objs = DeepFace.analyze(img_path = "img_cus4.jpeg", 
        actions = ['age', 'gender', 'race', 'emotion']
)
