# %%
from deepface import DeepFace
import pandas as pd

# %%
result = DeepFace.verify(img1_path = "img1.jpg", img2_path = "img2.jpg")
print(result)

# %%
dfs = DeepFace.find(img_path = "img1.jpg", db_path = "C:/Users/Owner/Documents/python/my_db")
# Out:
# WARNING: Representations for images in C:/Users/Owner/Documents/python/my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  25  representations found in  representations_vgg_face.pkl
# find function lasts  4.473167419433594  seconds

# %%
print(dfs)
# Out:
# [                                          identity  source_x  source_y  \
# 0   C:/Users/Owner/Documents/python/my_db/img4.jpg       345       211
# 1   C:/Users/Owner/Documents/python/my_db/img2.jpg       345       211
# 2   C:/Users/Owner/Documents/python/my_db/img6.jpg       345       211
# 3   C:/Users/Owner/Documents/python/my_db/img7.jpg       345       211
# 4   C:/Users/Owner/Documents/python/my_db/img5.jpg       345       211
# 5  C:/Users/Owner/Documents/python/my_db/img11.jpg       345       211
# 6  C:/Users/Owner/Documents/python/my_db/img10.jpg       345       211
#
#    source_w  source_h  VGG-Face_cosine
# 0       769       769         0.236399
# 1       769       769         0.255519
# 2       769       769         0.297387
# 3       769       769         0.311652
# 4       769       769         0.318022
# 5       769       769         0.357746
# 6       769       769         0.381215  ]

# %%
type(dfs)
# Out:
# list

# %% [markdown]
# VGG-Face нь нүүрний зургийг 2622 хэмжээст вектор хэлбэрээр илэрхийлдэг.

# %%
embedding_objs = DeepFace.represent(img_path = "img1.jpg")

# %%
print(embedding_objs)
# Out:
# [{'embedding': [-0.002614526078104973, -0.00823619868606329, 0.011225772090256214, 0.01757882535457611, -0.005616511683911085, 0.002301921136677265, 0.014863891527056694, 0.015004007145762444, -0.0011197116691619158, 0.01187437679618597, 0.017517291009426117, -0.0036513928789645433, 0.018969766795635223, 0.006984584499150515, 0.005077709443867207, 0.0006302819238044322, 0.00716051459312439, 0.01440108846873045, 0.005679194815456867, 0.007317480631172657, 0.0040829479694366455, 0.009948552586138248, 0.005831670947372913, 0.0072077601216733456, 0.004368254449218512, 0.006346854846924543, 0.0025794580578804016, 0.01134584192186594, 0.012351137585937977, 0.022621437907218933, 0.010355954058468342, -0.007207393180578947, -0.01899215765297413, 0.013779348693788052, 0.010550866834819317, -0.010726502165198326, 0.0014911424368619919, -0.006964257452636957, -0.0038637258112430573, -0.011070185340940952, 0.008750665001571178, -0.0021074675023555756, -0.007013794034719467, -0.012620454654097557
# ...

# %%
embedding = embedding_objs[0]["embedding"]
assert isinstance(embedding, list)
assert model_name = "VGG-Face" and len(embedding) == 2622
# Out:
#   Cell In[61], line 3
#     assert model_name = "VGG-Face" and len(embedding) == 2622
#                       ^
# SyntaxError: invalid syntax

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

#face verification
result = DeepFace.verify(img1_path = "img1.jpg", 
      img2_path = "img2.jpg", 
      model_name = models[0]
)

#face recognition
dfs = DeepFace.find(img_path = "img1.jpg",
      db_path = "C:/Users/Owner/Documents/python/my_db", 
      model_name = models[1]
)

#embeddings
embedding_objs = DeepFace.represent(img_path = "img1.jpg", 
      model_name = models[2]
)
# Out:
# Finding representations:   0%|          | 0/23 [00:00<?, ?it/s]
# facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: C:\Users\Owner\.deepface\weights\facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [04:17<00:00, 357kB/s]
# Finding representations: 100%|██████████| 23/23 [04:33<00:00, 11.91s/it]
# Representations stored in C:/Users/Owner/Documents/python/my_db/representations_facenet.pkl file.Please delete this file when you add new identities in your database.
# find function lasts  274.55849599838257  seconds
# facenet512_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet512_weights.h5
# To: C:\Users\Owner\.deepface\weights\facenet512_weights.h5
# 100%|██████████| 95.0M/95.0M [04:19<00:00, 366kB/s]

# %%
print(result,dfs)
# Out:
# {'verified': True, 'distance': 0.2555188743237228, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 345, 'y': 211, 'w': 769, 'h': 769}, 'img2': {'x': 516, 'y': 192, 'w': 512, 'h': 512}}, 'time': 2.11} [                                          identity  source_x  source_y  \
# 0  C:/Users/Owner/Documents/python/my_db/img11.jpg       345       211
# 1   C:/Users/Owner/Documents/python/my_db/img7.jpg       345       211
# 2  C:/Users/Owner/Documents/python/my_db/img10.jpg       345       211
# 3   C:/Users/Owner/Documents/python/my_db/img6.jpg       345       211
# 4   C:/Users/Owner/Documents/python/my_db/img4.jpg       345       211
# 5   C:/Users/Owner/Documents/python/my_db/img5.jpg       345       211
#
#    source_w  source_h  Facenet_cosine
# 0       769       769        0.184639
# 1       769       769        0.193672
# 2       769       769        0.221739
# 3       769       769        0.230715
# ...

# %%
print(embedding_objs)
# Out:
# [{'embedding': [-0.8791570663452148, 0.26306936144828796, -0.7709915637969971, -0.49304264783859253, 1.2072803974151611, -0.3580583930015564, 2.059868097305298, 1.2563663721084595, 0.5170804262161255, -0.7894969582557678, -0.18783101439476013, 1.7585023641586304, 0.34811270236968994, -1.669093132019043, -1.855522632598877, 0.5511308312416077, 0.18396826088428497, -0.019266823306679726, -0.750481367111206, -0.8711652755737305, -0.37641119956970215, 0.7099037766456604, -1.4903262853622437, -0.1350366324186325, 0.28596732020378113, 0.8297253251075745, 0.36786359548568726, -1.4145208597183228, -0.9364782571792603, 0.6098508834838867, 0.28226399421691895, -0.9835452437400818, 1.6239004135131836, -0.6986181139945984, -0.17589280009269714, 0.3912913501262665, 0.18730738759040833, -0.8760466575622559, 0.5722121000289917, 0.19979795813560486, 0.404935747385025, -2.706211566925049, 0.13733406364917755, -0.6060850620269775, -1.0185924768447876, 0.726033091545105, -1.2209490537643433, 0.77178227
# ...

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]

#face verification
result_1 = DeepFace.verify(img1_path = "img1.jpg", 
          img2_path = "img2.jpg", 
          distance_metric = metrics[1]
)

#face recognition
dfs_1 = DeepFace.find(img_path = "img1.jpg", 
          db_path = "C:/Users/Owner/Documents/python/my_db", 
          distance_metric = metrics[2]
)
# Out:
# WARNING: Representations for images in C:/Users/Owner/Documents/python/my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  25  representations found in  representations_vgg_face.pkl
# find function lasts  1.033431053161621  seconds

# %%
objs = DeepFace.analyze(img_path = "img2.jpg", 
        actions = ['age', 'gender', 'race', 'emotion']
)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Owner\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:01<00:00, 4.23MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Owner\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [09:03<00:00, 992kB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Owner\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [08:08<00:00, 1.10MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
print(objs)
# Out:
# [{'age': 31, 'region': {'x': 516, 'y': 192, 'w': 512, 'h': 512}, 'gender': {'Woman': 99.99998807907104, 'Man': 1.7813232489061193e-05}, 'dominant_gender': 'Woman', 'race': {'asian': 0.00212914830711113, 'indian': 0.006679906732143776, 'black': 0.00016294748424311122, 'white': 97.56857185738423, 'middle eastern': 1.7255281835164804, 'latino hispanic': 0.6969290886009826}, 'dominant_race': 'white', 'emotion': {'angry': 6.092552095651627, 'disgust': 0.006077899161027744, 'fear': 29.299819469451904, 'happy': 9.73166972398758, 'sad': 20.32298594713211, 'surprise': 8.743562549352646, 'neutral': 25.80333650112152}, 'dominant_emotion': 'fear'}]

# %%
backends = [
  'opencv', 
  'ssd', 
  'dlib', 
  'mtcnn', 
  'retinaface', 
  'mediapipe',
  'yolov8',
  'yunet',
]

#face verification
obj = DeepFace.verify(img1_path = "img1.jpg", 
        img2_path = "img2.jpg", 
        detector_backend = backends[0]
)

#face recognition
dfs = DeepFace.find(img_path = "img1.jpg", 
        db_path = "C:/Users/Owner/Documents/python/my_db", 
        detector_backend = backends[1]
)

#embeddings
embedding_objs = DeepFace.represent(img_path = "img1.jpg", 
        detector_backend = backends[2]
)

#facial analysis
demographies = DeepFace.analyze(img_path = "img2.jpg", 
        detector_backend = backends[3]
)

#face detection and alignment
face_objs = DeepFace.extract_faces(img_path = "img2.jpg", 
        target_size = (224, 224), 
        detector_backend = backends[4]
)
# Out:
# WARNING: Representations for images in C:/Users/Owner/Documents/python/my_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  24  representations found in  representations_vgg_face.pkl
# deploy.prototxt will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv/raw/3.4.0/samples/dnn/face_detector/deploy.prototxt
# To: C:\Users\Owner\.deepface\weights\deploy.prototxt
# 28.1kB [00:00, 14.1MB/s]
# res10_300x300_ssd_iter_140000.caffemodel will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# To: C:\Users\Owner\.deepface\weights\res10_300x300_ssd_iter_140000.caffemodel
# 100%|██████████| 10.7M/10.7M [00:02<00:00, 3.79MB/s]
# find function lasts  8.155190229415894  seconds
# ...
