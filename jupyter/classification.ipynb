# %%
from sklearn import svm
X = [[0, 0], [1, 1]]
y = [0, 1]
clf = svm.SVC()
clf.fit(X, y)
# Out:
# SVC()

# %%
clf.predict([[-10,5]])
# Out:
# array([0])

# %%
X = [[0], [1], [2], [3]]
Y = [0, 1, 2, 3]
clf = svm.SVC(decision_function_shape='ovo')
clf.fit(X, Y)
# Out:
# SVC(decision_function_shape='ovo')

# %% [markdown]
# LINEAR REGRESSION

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)  #налалтын өнцөг, 
#x=0 үеийн утга, кор коэф

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# Predict---10 years old car's speed

# %%
speed=myfunc(10)
print(speed)
# Out:
# 85.59308314937454

# %% [markdown]
# Bad fit

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
print(r)
# Out:
# 0.01331814154297491

# %% [markdown]
# Polynomial Regression

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3)) #3 н зэргийн олон гишүүнт

myline = numpy.linspace(1, 22, 100)  #1, 22 эхний 1-22 дахь цэгүүдийг холбоно 100-графикт огтлолцох цэгийн тоо

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# Хамааралтай эсэх
# 1 тэй ойрхон бол сайн хамааралтай
# 0 бол хамааралгүй

# %%
import numpy
from sklearn.metrics import r2_score
print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451025

# %%
print(myline)
# Out:
# [ 1.          1.21212121  1.42424242  1.63636364  1.84848485  2.06060606
#   2.27272727  2.48484848  2.6969697   2.90909091  3.12121212  3.33333333
#   3.54545455  3.75757576  3.96969697  4.18181818  4.39393939  4.60606061
#   4.81818182  5.03030303  5.24242424  5.45454545  5.66666667  5.87878788
#   6.09090909  6.3030303   6.51515152  6.72727273  6.93939394  7.15151515
#   7.36363636  7.57575758  7.78787879  8.          8.21212121  8.42424242
#   8.63636364  8.84848485  9.06060606  9.27272727  9.48484848  9.6969697
#   9.90909091 10.12121212 10.33333333 10.54545455 10.75757576 10.96969697
#  11.18181818 11.39393939 11.60606061 11.81818182 12.03030303 12.24242424
#  12.45454545 12.66666667 12.87878788 13.09090909 13.3030303  13.51515152
#  13.72727273 13.93939394 14.15151515 14.36363636 14.57575758 14.78787879
#  15.         15.21212121 15.42424242 15.63636364 15.84848485 16.06060606
#  16.27272727 16.48484848 16.6969697  16.90909091 17.12121212 17.33333333
# ...

# %%
import numpy
import matplotlib.pyplot as plt

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
myline = numpy.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# Дата хоорондоо бага хамааралтай бөгөөд олон зэргийн регресс тохиромжгүйг r2_score- гаргав

# %%
import numpy
from sklearn.metrics import r2_score

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652

# %% [markdown]
# Multiple Regression

# %%
import pandas
df = pandas.read_csv("C:/Users/Owner/Downloads/data.csv")
X = df[['Weight', 'Volume']]  #independent value
y = df['CO2']  #dependent value
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# weight=2300, volume=1300 үе дэх CO2-н таамаглал

# %%
predictedCO2 = regr.predict([[2300, 1300]])
print(predictedCO2)
# Out:
# [107.2087328]
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Регрессийн коэффициентийг хэвлэх
# Weight , Volume-н нөлөөлөл

# %%
#Scale Гараас оруулсан датаны нэгж нь ялгаатай утгатай бол StandardScaler() ашиглаж нэг утгатай болгоно. 
#Ж.нь: Литр, см^3 ээр өгөгдсөн тохиолдол:
print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

df = pandas.read_csv("C:/Users/Owner/Downloads/data.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

scaledX = scale.fit_transform(X)

regr = linear_model.LinearRegression()
regr.fit(scaledX, y)

scaled = scale.transform([[2300, 1300]])
predictedCO2 = regr.predict([scaled[0]])
print(predictedCO2)
# Out:
# [107.2087328]
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Data set
# Х тэнхлэгт худалдан авалт хийхийн өмнөх хугацаа
# У тэнхлэгт худалдан авалтанд зарцуулдаг мөнгөний хэмжээг харуулав

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Датгаа сургалтын болон тестийн гэж 2 хуваах

# %%
train_x = x[:80]  # Сургалтын датасэт 1-80 хүртэлх элемент
train_y = y[:80]

test_x = x[80:]  # тестлэх датасэт 80-100 хүртэлх элемент
test_y = y[80:]

plt.subplot(1, 2, 1)
plt.scatter(train_x, train_y)  # сургалтын датаг харуулах

plt.subplot(1, 2, 2)
plt.scatter(test_x, test_y) # тестийн датаг харуулах
plt.show()

# %% [markdown]
# Fit the data set
# 4-н зэргийн олон гишүүнт модел гаргав

# %%
mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))
myline=numpy.linspace(0,6,100)
plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
a=mymodel(train_x)
print(a)
# Out:
# [ 60.61029983  58.98870236 191.43527077  17.92238274 123.73695777
#   62.94603853  49.68158491  73.77721174  67.02440621  63.88591562
#   48.39936139  42.43414561  58.07664133  68.79733262  48.73312943
#   61.13718922  58.67395535  28.31833431  62.00793488  58.40995414
#   63.42268895  59.664838    55.0374632   65.36331253  60.40342129
#   60.05036182  61.31674995  71.30071375  84.02072564  59.64826923
#   60.17791713  36.88489817 284.4262487   57.23518052  52.80822333
#   22.87043209  49.70787016  62.97616976  58.49693262  48.64485892
#   60.32759576  41.84112922 135.52134021  17.68902706  20.35017942
#   60.39431171  46.72657889  58.00700464  62.79672634  57.54879518
#   34.15321489  60.51914287  60.50488312  59.12967518  51.38927704
#   25.12795981  61.30267596  49.53951069  55.72476309 133.94225266
#   60.61672908  59.52345379  58.85178806  53.72981473 168.79327388
#   58.0256967   61.52688553  85.34524961  49.12480699  42.98100137
# ...

# %%
print(train_y)
# Out:
# [ 76.05204933  56.20180641 121.17874037  36.05903817 114.23885932
#  117.41526024  63.77986643  95.52998052  62.4237197   60.57574247
#   38.57519009  24.10914678  37.45148182  67.13926856  39.26265343
#   53.79918302  40.94657678  27.02857247 111.90190427  30.26663537
#   51.4368334   58.83311239  42.08623741  83.01076429  68.37843898
#   72.54627253  76.22874513  60.83111238 123.11113005  27.89501382
#   53.25015791  24.86406278 190.30762228  55.79245737  42.32964984
#   43.76381026  25.90093643  85.28325651  56.63901768  43.77321677
#   34.70979433  37.10649687  77.86225629  14.09666443  62.93869329
#   70.87521926  61.39097018  43.58292288  81.92492065  57.61442568
#   43.5111781   57.3316853   53.67848811  22.97550427  50.79538368
#   39.01941998  82.32095959  39.62788318  68.30365792 115.73628743
#   38.66530343  65.39332448  44.34023444  30.00934597 161.50533328
#   59.1743156   68.74904453 108.8692008   89.19445659  48.95077634
# ...

# %% [markdown]
# Моделийн тооцоолсон дата болон ашигласан сургалтын датаны хоорондын хамаарал

# %%
from sklearn.metrics import r2_score
r2=r2_score(train_y, mymodel(train_x)) #сургалтанд ашигласан y- утга, 
#моделиор гарч ирсэн y-н хоорондын хамаарал
print(r2)
# Out:
# 0.7988645544629798

# %% [markdown]
# Моделийн хамаарлаа шалгасны дараа тестийн датагаа оруулах

# %%
import numpy
from sklearn.metrics import r2_score
x=numpy.random.normal(3,1,100)
y=numpy.random.normal(150, 40,100)/ x
train_x=x[:80]
train_y=y[:80]
test_x=x[80:]
test_y=y[80:]
mymodel=numpy.poly1d(numpy.polyfit(train_x, train_y, 4))
r2=r2_score(test_y, mymodel(test_x))
print(r2)
# Out:
# 0.7128755745170752

# %% [markdown]
# Модельд тест хийхээр х-ийн утгыг оруулж гарсан у-г бодит у-тэй харьцуулахад r_square нь өндөр тоо гарсан тул моделийг цаашид ашиглаж болно.

# %% [markdown]
# Моделоо тест хийсний дараа гараас тоон утга оруулж таамаглана. Дээрх жишээн дээр дэлгүүрт худалдан авалт хийх хугацаа болон хэр их мөнгө зарцуулалтын хоорондын хамаарлын модель сургасан бөгөөд одоо худалдан авагч 5мин дэлгүүрт зарцуулахад хэдэн төгрөгний худалдан авалт хийх магадлалтай вэ?

# %%
print(mymodel(5))
# Out:
# 48.690054421900754

# %% [markdown]
# Machine Learning - Decision Tree
# Бүх дата тоон хэлбэртэй байх хэрэгтэй, тоо биш бол (хүйс, үндэс ...) хувиргана
# map() арга ашиглан мэдээллийг тоо руу хөрвүүлнэ
#
# d = {'UK': 0, 'USA': 1, 'N': 2}
# df['Nationality'] = df['Nationality'].map(d)
# d = {'YES': 1, 'NO': 0}
# df['Go'] = df['Go'].map(d)

# %%
import pandas
df = pandas.read_csv("C:/Users/Owner/Documents/python/DATA.csv")
print(df)
# Out:
#        Unnamed: 0        Olgoson ognoo  Olgoson dvn   Vndsen zeel  \
# 0               0  2019-12-28 00:00:00       170000  170000.00000
# 1               1  2020-08-26 00:00:00       170000  166323.99960
# 2               2  2020-09-10 00:00:00       100000   51558.01359
# 3               3  2020-11-17 00:00:00       200000  118109.90210
# 4               4  2020-11-29 00:00:00       175000   49374.22825
# ...           ...                  ...          ...           ...
# 21907       21907  2022-06-13 00:00:00       180000  179999.74050
# 21908       21908  2022-06-13 00:00:00       150000  149999.99650
# 21909       21909  2022-06-14 00:00:00        50000   50000.00000
# 21910       21910  2022-06-14 00:00:00       190000  189999.04650
# 21911       21911  2022-06-14 00:00:00       170000  169911.58980
#
#          Vndsen hvv  Nemegdvvlsen hvv  Used day  XXX day  HH
# 0      313547.62330       19026.66490       946      383   1
# ...

# %% [markdown]
# Багануудыг онцлогоор нь салгана онцлогтой нь X-д, гаралт нь y- байна

# %%
features=['Olgoson dvn', 'Vndsen zeel', 'Vndsen hvv', 'Used day']
data = pandas.DataFrame(features)
X=df[features]
y=df['HH']
print(X)
print(y)
# Out:
#        Olgoson dvn   Vndsen zeel    Vndsen hvv  Used day
# 0           170000  170000.00000  313547.62330       946
# 1           170000  166323.99960  117002.04310       704
# 2           100000   51558.01359   40215.25170       689
# 3           200000  118109.90210   16771.60580       621
# 4           175000   49374.22825   20539.67968       609
# ...            ...           ...           ...       ...
# 21907       180000  179999.74050    7199.98960        48
# 21908       150000  149999.99650    7499.99975        48
# 21909        50000   50000.00000    2500.00000        47
# 21910       190000  189999.04650    9119.95416        47
# 21911       170000  169911.58980    4077.87816        47
#
# [21912 rows x 4 columns]
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 21907    0
# 21908    0
# 21909    0
# 21910    0
# 21911    0
# Name: HH, Length: 21912, dtype: int64

# %% [markdown]
# Бодит desicion tree датандаа тааруулан үүсгэнэ

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4310145753358925, 0.9666666666666667, 'Used day <= 64.5\ngini = 0.322\nsamples = 21912\nvalue = [17494, 4418]'),
#  Text(0.15128658829174665, 0.9, 'Used day <= 31.5\ngini = 0.058\nsamples = 17092\nvalue = [16584, 508]'),
#  Text(0.14744781669865642, 0.8333333333333334, 'gini = 0.0\nsamples = 11808\nvalue = [11808, 0]'),
#  Text(0.15512535988483686, 0.8333333333333334, 'Vndsen hvv <= 7840.0\ngini = 0.174\nsamples = 5284\nvalue = [4776, 508]'),
#  Text(0.08247360844529751, 0.7666666666666667, 'Olgoson dvn <= 97500.0\ngini = 0.068\nsamples = 3770\nvalue = [3638, 132]'),
#  Text(0.03934740882917467, 0.7, 'Vndsen hvv <= 5164.982\ngini = 0.165\nsamples = 1116\nvalue = [1015, 101]'),
#  Text(0.028790786948176585, 0.6333333333333333, 'Vndsen hvv <= 3243.6\ngini = 0.072\nsamples = 1048\nvalue = [1009, 39]'),
#  Text(0.019193857965451054, 0.5666666666666667, 'Vndsen hvv <= 556.631\ngini = 0.012\nsamples = 809\nvalue = [804, 5]'),
# ...

# %% [markdown]
# gini-хуваалтын чанарыг илэрхийлэх ба 0-0.5н хооронд бн 0 бүх samples нэг үр дүнд хүрнэ, 0.5 нь яг голоор нь хуваана Gini = 1 - (x/n)^2 - (y/n)^2
# x-үр дүнгийн 1 гэсэн хэсэг
# y-үр дүнгийн 0 гэсэн хариултын тоо
# samples нийт датаны тоо
# value- датаны хуваагдлын тоо

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Olgoson ognoo        object
# Olgoson dvn           int64
# Vndsen zeel         float64
# Vndsen hvv          float64
# Nemegdvvlsen hvv    float64
# Used day              int64
# XXX day               int64
# HH                    int64
# dtype: object

# %% [markdown]
# Шийдвэрийн модод гараас утга оруулж таамаглалыг шалгана.1 гарвал зээлдэгч хугацаа хэтрэнэ, 0 бол эсрэгээрээ

# %%
print(dtree.predict([[200000, 200000,50000,10]]))
# Out:
# [0]
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 100)
predicted = numpy.random.binomial(1,.9,size = 100)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
Accuracy = metrics.accuracy_score(actual, predicted)
Precision = metrics.precision_score(actual, predicted)
Sensitivity_recall = metrics.recall_score(actual, predicted)
Specificity = metrics.recall_score(actual, predicted, pos_label=0)
F1_score = metrics.f1_score(actual, predicted)

# %%
#metrics
print({"Accuracy":Accuracy,"Precision":Precision,"Sensitivity_recall":Sensitivity_recall,"Specificity":Specificity,"F1_score":F1_score})
# Out:
# {'Accuracy': 0.83, 'Precision': 0.8829787234042553, 'Sensitivity_recall': 0.9325842696629213, 'Specificity': 0.0, 'F1_score': 0.907103825136612}

# %% [markdown]
# Hierarchical Clustering
# Хоорондох зай нь богино датаг нэг бүлэгт  оруулдаг

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = list(zip(x, y)) 
#[(4, 21), (5, 19), (10, 24), (4, 17), (3, 16), (11, 25), (14, 24), (6, 22), (10, 21), (12, 21)]

linkage_data = linkage(data, method='ward', metric='euclidean')
#Compute the linkage between all of the different points. Here we use a simple euclidean distance measure and Ward's linkage, which seeks to minimize the variance between clusters.
dendrogram(linkage_data)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = list(zip(x, y))

hierarchical_cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
labels = hierarchical_cluster.fit_predict(data)

plt.scatter(x, y, c=labels)
plt.show()
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %% [markdown]
# Logistic Regression
