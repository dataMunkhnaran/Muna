# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import seaborn as sns 

df = pd.read_csv("C:/Users/Owner/Downloads/sungaltt.csv")
print(df)
#df.plot()
#plt.show()
# Out:
#           CustCode      AcntNo  AdvAmt  BeginDate  ClosedDate     EndDate  \
# 0       1020000019  2122010303   80000  1/17/2022   2/21/2022   3/16/2022
# 1       1020000019  2122033933   80000  2/21/2022   3/19/2022   3/21/2022
# 2       1020000019  2122055899  110000  3/24/2022   4/25/2022   4/25/2022
# 3       1020000019  2122078073  110000   5/1/2022   8/10/2022    8/8/2022
# 4       1020000019  2122129267   50000  8/10/2022   9/12/2022   9/12/2022
# ...            ...         ...     ...        ...         ...         ...
# 734928  1023061025  2123240453   70000  9/18/2023  0001-01-01   10/5/2023
# 734929  1023062025  2123240381   50000  9/18/2023  0001-01-01   10/5/2023
# 734930  1023062249  2123240472   50000  9/18/2023  0001-01-01  10/15/2023
# 734931  1023063038  2123240274  150000  9/18/2023  0001-01-01  10/11/2023
# 734932  1023063497  2123240756   80000  9/18/2023  0001-01-01  10/19/2023
#
#         PymntDate  rank  ExtCnt  UsedDays  ArrDays  ArrCount
# ...

# %%
sns.countplot(data=df[df["ExtCnt"]>0], x='ExtCnt').set(title='Сунгалтын тоо')
# Out:
# [Text(0.5, 1.0, 'Сунгалтын тоо')]

# %%
dff=pd.read_csv("C:/Users/Owner/Downloads/last.csv")
dff
# Out:
#         AdvAmt  count
# 0          0.0      5
# 1      20000.0   6940
# 2      25000.0   5093
# 3      30000.0   6011
# 4      35000.0   3584
# ..         ...    ...
# 172  2500000.0      1
# 173  2800000.0      1
# 174  3000000.0      3
# 175  4400000.0      1
# 176  5000000.0      1
#
# [177 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 4))
sns.barplot(data=dff[dff["AdvAmt"]<100000],  y="AdvAmt", x="count",color='steelblue')
# Out:
# <Axes: xlabel='count', ylabel='AdvAmt'>

# %%
x=np.array(df['AdvAmt'])
y=np.array(df['ExtCnt'])
p=1

# %%
sns.lmplot(data=df, x='AdvAmt', y='ExtCnt', ci=False)
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
formula= 'AdvAmt~ExtCnt'
result=smf.ols(formula, df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 AdvAmt   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6685.
# Date:                Mon, 18 Sep 2023   Prob (F-statistic):               0.00
# Time:                        18:05:31   Log-Likelihood:            -9.4571e+06
# No. Observations:              734933   AIC:                         1.891e+07
# Df Residuals:                  734931   BIC:                         1.891e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.336e+05    118.023   1131.641      0.000    1.33e+05    1.34e+05
# ...

# %%
sns.violinplot(data = df[df['AdvAmt'] <300000], x = 'ExtCnt', y = 'AdvAmt')
# Out:
# <Axes: xlabel='ExtCnt', ylabel='AdvAmt'>

# %%
sns.boxplot(data = df[df['AdvAmt'] < 10**6], x = 'ExtCnt', y = 'AdvAmt')
# Out:
# <Axes: xlabel='ExtCnt', ylabel='AdvAmt'>

# %%
sns.countplot(data = df, x = 'ExtCnt')
# Out:
# <Axes: xlabel='ExtCnt', ylabel='count'>

# %%
df=pd.read_csv("C:/Users/Owner/Downloads/extRqst.csv")
df
# Out:
#          TxnDate   Status  count
# 0     2020-06-27  Success      1
# 1     2020-06-29  Success      4
# 2     2020-06-30  Success      8
# 3     2020-07-01  Success     39
# 4     2020-07-02  Success     43
# ...          ...      ...    ...
# 1323  2023-09-17  Deleted     93
# 1324  2023-09-18  Success    930
# 1325  2023-09-18  Deleted     72
# 1326  2023-09-19     Rqst    190
# 1327  2023-09-19  Success     73
#
# [1328 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.lineplot(data=df, x='TxnDate', y='count' ,  hue='Status')
# Out:
# <Axes: xlabel='TxnDate', ylabel='count'>

# %%
#fig, ax = plt.subplots(figsize=(40, 10))
sns.lineplot(data=df1, x='AdvDate', y='sum', )
# Out:
# <Axes: xlabel='AdvDate', ylabel='sum'>

# %%
df=pd.read_excel("C:/Users/Owner/Downloads/profitgrap.xlsx")
df
# Out:
#         AdvAmt  useddays      15 хоног   10 хоног       7 хоног           0.1  \
# 0      20000.0      34.0  4.860000e+03     4860.0  4.860000e+03  6.860000e+03
# 1      25000.0      36.0  5.300000e+03     5300.0  5.300000e+03  7.800000e+03
# 2      30000.0      37.0  5.720000e+03     5720.0  5.720000e+03  8.720000e+03
# 3      35000.0      37.0  6.090000e+03     6090.0  6.090000e+03  9.590000e+03
# 4      40000.0      41.0  6.780000e+03     6780.0  6.780000e+03  1.078000e+04
# ..         ...       ...           ...        ...           ...           ...
# 145   800000.0      64.0  1.096667e+05   110800.0  1.125429e+05  1.896667e+05
# 146   910000.0     748.0  1.414227e+06  1438160.0  1.469217e+06  1.505227e+06
# 147  1000000.0      68.0  1.435333e+05   144800.0  1.467143e+05  2.435333e+05
# 148  1450000.0      83.0  2.492333e+05   251000.0  2.535571e+05  3.942333e+05
# 149        NaN       NaN           NaN        NaN           NaN           NaN
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.lineplot(data = df[df['AdvAmt'] <= 800000], x = 'AdvAmt', y = '7day').set(title='7 болон 10 хоног сунгаснаар үүссэн алдагдал дунджаар')
sns.lineplot(data = df[df['AdvAmt'] <= 800000], x = 'AdvAmt', y = '10day')
# Out:
# <Axes: title={'center': '7 болон 10 хоног сунгаснаар үүссэн алдагдал дунджаар'}, xlabel='AdvAmt', ylabel='7day'>

# %%
ff=pd.read_excel("C:/Users/Owner/Downloads/Datahuwiar.xlsx")
ff
# Out:
#         AdvAmt         1huwi       1.5huwi         2huwi       2.5huwi  \
# 0      20000.0 -1.845882e+03 -1.745882e+03 -1.645882e+03 -1.545882e+03
# 1      25000.0 -1.533333e+03 -1.408333e+03 -1.283333e+03 -1.158333e+03
# 2      30000.0 -1.307027e+03 -1.157027e+03 -1.007027e+03 -8.570270e+02
# 3      35000.0 -1.187027e+03 -1.012027e+03 -8.370270e+02 -6.620270e+02
# 4      40000.0 -5.492683e+02 -3.492683e+02 -1.492683e+02  5.073171e+01
# ..         ...           ...           ...           ...           ...
# 145   800000.0  1.246667e+04  2.153333e+04  3.060000e+04  3.966667e+04
# 146   910000.0  3.159200e+05  5.337133e+05  7.515067e+05  9.693000e+05
# 147  1000000.0  1.900000e+04  3.166667e+04  4.433333e+04  5.700000e+04
# 148  1450000.0  4.240000e+04  6.801667e+04  9.363333e+04  1.192500e+05
# 149        NaN  1.042778e+06  2.226089e+06  3.409400e+06  4.592710e+06
#
#             3huwi       3.5huwi         4huwi       4.5huwi         5huwi
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
data = ff[ff['AdvAmt'] >250000] 
sns.lineplot(data = data, x = 'AdvAmt', y = '1huwi').set(title='Сунгалтын шимтгэл')
#sns.lineplot(data = data, x = 'AdvAmt', y = '1.5huwi')
#sns.lineplot(data = data, x = 'AdvAmt', y = '2huwi')
sns.lineplot(data = data, x = 'AdvAmt', y = '2.5huwi')
#sns.lineplot(data = data, x = 'AdvAmt', y = '3huwi')
#sns.lineplot(data = data, x = 'AdvAmt', y = '3.5huwi')
#sns.lineplot(data = data, x = 'AdvAmt', y = '4huwi')
#sns.lineplot(data = data, x = 'AdvAmt', y = '4.5huwi')
sns.lineplot(data = data, x = 'AdvAmt', y = '5huwi')
# Out:
# <Axes: title={'center': 'Сунгалтын шимтгэл'}, xlabel='AdvAmt', ylabel='1huwi'>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
data = ff[ff['AdvAmt'] <= 800000]
sns.lineplot(data = data, x = 'AdvAmt', y = '1huwi').set(title='Сунгалтын шимтгэл')
# Out:
# [Text(0.5, 1.0, 'Сунгалтын шимтгэл')]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Owner\Documents\python\sungalt.ipynb Cell 16 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(15, 5))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a> sns.lineplot(data = ff, x = 'AdvAmt', y = '1huwi', y1 = '1.5huwi').set(title='Сунгалтын шимтгэл')
#
# ...

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
x = k['AdvAmt']
y = k['total_num_ext']
y1=k['total_num_acntno' ]
plt.plot(x,y,'r' )
plt.plot(x,y1,'b')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.lineplot(data = k[k['AdvAmt'] <= 500000], x = 'AdvAmt', y =  'total_num_ext') 
sns.lineplot(data = k[k['AdvAmt'] <= 500000], x = 'AdvAmt', y = 'total_num_acntno').set(title='Нийт сунгалтын тоо болон зээлийн дансны тоо зээлийн хэмжээнээс хамаарч')
# Out:
# [Text(0.5, 1.0, 'Нийт сунгалтын тоо болон зээлийн дансны тоо зээлийн хэмжээнээс хамаарч')]

# %%
plt.figure(figsize=(10, 7))
sns.lineplot(data = k[k['AdvAmt'] <= 500000], x = 'total_num_acntno', y =  'total_num_ext').set(title='Зээлийн дансны тоо болон сунгалт')
# Out:
# [Text(0.5, 1.0, 'Зээлийн дансны тоо болон сунгалтын хамаарал')]

# %%
import numpy as np
import matplotlib.pyplot as plt
df1=pd.read_csv("C:/Users/Owner/Downloads/hugatsaa_hetersen_dans_too.csv")
#plt.figure(figsize=(10, 5))
sns.lineplot(data = df1[df1['zeeliin_dansnii_too']<150], x = 'zeeliin_dansnii_too', y = 'hugatsaa_hetersen_dans').set(title= 'Зээлийн дансны тоо болон хугацаа хэтрэлт')
# Out:
# [Text(0.5, 1.0, 'Зээлийн дансны тоо болон хугацаа хэтрэлт')]

# %%
# Out:
# 0        20000.0
# 1        25000.0
# 2        30000.0
# 3        35000.0
# 4        40000.0
#          ...
# 144     765000.0
# 145     800000.0
# 146     910000.0
# 147    1000000.0
# 148    1450000.0
# Name: AdvAmt, Length: 149, dtype: float64

# %%
#fig, ax = plt.subplots(figsize=(40, 10))
sns.lineplot(data=df1,data=df, x='AdvDate', y='count' )
# Out:
#   Cell In[41], line 2
#     sns.lineplot(data=df1,data=df, x='AdvDate', y='count' )
#                           ^
# SyntaxError: keyword argument repeated: data

# %%
AdvAmtt=(df['AdvAmt'].to_string(index=False))
sungalt=df['ExtCnt'].to_string(index=False)
plt.scatter(df['AdvAmt'], df['ExtCnt'])
plt.xlabel("Зээлийн хэмжээ")
plt.ylabel("Сунгалтын тоо")
plt.show()

# %%
df.corr()
# Out:
#              AcntNo  CustCode    AdvAmt    ExtCnt  LnCrntLmt
# AcntNo     1.000000  0.254529  0.031531  0.054849  -0.096481
# CustCode   0.254529  1.000000 -0.323349 -0.006084  -0.441958
# AdvAmt     0.031531 -0.323349  1.000000  0.107889   0.616235
# ExtCnt     0.054849 -0.006084  0.107889  1.000000   0.017356
# LnCrntLmt -0.096481 -0.441958  0.616235  0.017356   1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import seaborn as sns 

df = pd.read_csv("C:/Users/Owner/Downloads/sungaltneg.csv")
print(df)
#df.plot()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Owner\Documents\python\sungalt.ipynb Cell 18 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> import statsmodels.formula.api as smf
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a> df = pd.read_csv("C:/Users/Owner/Downloads/sungaltneg.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a> print(df)
#      <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a> #df.plot()
# ...

# %%
df=pd.read_csv("C:/Users/Owner/Downloads/advamt_sungasandans.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Owner\Documents\python\sungalt.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df=pd.read_csv("C:/Users/Owner/Downloads/advamt_sungasandans.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> df
#
# NameError: name 'pd' is not defined

# %%
sns.lineplot(data=df[df['AdvAmt'] <= 0000], x='AdvAmt', y='count').set(title='500k-с бага Зээлийн хэмжээ болон зээлийн дансны тоо')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Owner\Documents\python\sungalt.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Owner/Documents/python/sungalt.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> sns.lineplot(data=df[df['AdvAmt'] <= 100000], x='AdvAmt', y='count').set(title='500k-с бага Зээлийн хэмжээ болон зээлийн дансны тоо')
#
# NameError: name 'sns' is not defined
